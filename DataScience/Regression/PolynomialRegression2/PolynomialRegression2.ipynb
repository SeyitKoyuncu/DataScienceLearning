# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Importing the dataset

# %%
dataset = pd.read_csv('Position_Salaries.csv')
x = dataset.iloc[:, 1:-1].values
y = dataset.iloc[:, -1].values

# %% [markdown]
# ## Implement Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression

linear_regression = LinearRegression()
linear_regression.fit(x,y)
predict_y = linear_regression.predict(x)

# %% [markdown]
# # Implement Polynomial Linear Regression Model

# %%
from sklearn.preprocessing import PolynomialFeatures

poly_reg =PolynomialFeatures(degree = 2)
x_poly = poly_reg.fit_transform(x)
linear_regression2 = LinearRegression()
linear_regression2.fit(x_poly,y) # [a,b,c] ==== a is equal to x^0, b is equal to x^1, c is equal to x^2. If we choose degree to 3 we have 4 variable for x^0, x^1, x^2, x^3 [a,b,c,d]
# Out:
# LinearRegression()

# %% [markdown]
# ## Visulazing The Linear Regression Result

# %%
plt.scatter(x,y)
plt.plot(x,predict_y, color = "red")
plt.title("Linear Regression")
plt.xlabel("Position Level")
plt.ylabel("Salary Label")
plt.show()

# %% [markdown]
# ## Visulazing The Polynomial Regression Result

# %%
plt.scatter(x,y)
plt.plot(x,linear_regression2.predict(x_poly), color = "red")
plt.title("Polynomial Regression")
plt.xlabel("Position Level")
plt.ylabel("Salary Label")
plt.show()

# %% [markdown]
# ## Visulazing the Polynomial Regression results (for higher resolution and smoother curve)

# %%
poly_reg2 = PolynomialFeatures(degree = 4)
x_poly2 = poly_reg2.fit_transform(x)
linear_regression3 = LinearRegression()
linear_regression3.fit(x_poly2,y)
# Out:
# LinearRegression()

# %%
X_grid = np.arange(min(x), max(x), 0.1)
X_grid = X_grid.reshape((len(X_grid),1))

plt.scatter(x,y)
plt.plot(X_grid,linear_regression3.predict(poly_reg2.fit_transform(X_grid)), color = "red")
plt.title("Polynomial Regression")
plt.xlabel("Position Level")
plt.ylabel("Salary Label")
plt.show()

# %% [markdown]
# ## Predicting a new result with Linear Regression

# %%
print(linear_regression.predict([[6.5]]))
# Out:
# [338466.66666667]

# %% [markdown]
# ## Predicting a new result with Polynomial Regression

# %%
predict_poly = poly_reg.fit_transform([[6.5]])

#with lower degree polynomial linear regression
print(linear_regression2.predict(predict_poly))
#print(linear_regression2.predict(poly_reg.fit_transform([[6.5]])))

#with higher degree polynomial linear regression
print(linear_regression3.predict(poly_reg2.fit_transform([[6.5]])))
# Out:
# [189498.10606061]
# [158862.45265155]
